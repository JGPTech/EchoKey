# %%
import numpy as np
from numba import cuda, njit
import time
import math
import logging
from dataclasses import dataclass
from typing import Dict, Tuple, List, Optional

# ------------------------- Handshake Patterns Definition ------------------------- #
# Define the handshake patterns and their corresponding frequency bands
HANDSHAKE_PATTERNS = {
    'control': {
        'dimension_10': ('1010', '0101'),
        'close_connection': ('1111', '0000')
    },
    'web_services': {
        'web_request': ('0001', '0010'),
        'file_transfer': ('0011', '0100'),
        'api_access': ('0101', '0110')
    },
    'financial_services': {
        'banking_transaction': ('0111', '1000'),
        'payment_processing': ('1001', '1010')
    },
    'computational_services': {
        'mathematical_operation': ('1011', '1100'),
        'data_analysis': ('1101', '1110')
    },
    'communication_services': {
        'messaging': ('1111', '0000'),
        'email_exchange': ('0000', '0001'),
        'voice_communication': ('0001', '0011')
    },
    'entertainment_services': {
        'streaming_access': ('0010', '0011'),
        'gaming_session': ('0100', '0101'),
        'content_download': ('0101', '0111')
    },
    'administrative_services': {
        'user_authentication': ('0110', '0111'),
        'network_configuration': ('1000', '1001'),
        'system_monitoring': ('1010', '1011')
    }
}

# Define acknowledgment patterns for each handshake (if applicable)
ACK_PATTERNS = {
    'ACK_dimension_10': ('1100', '0011'),
    'ACK_close_connection': ('0000', '1111'),
    'ACK_web_request': ('1101', '0100'),
    'ACK_file_transfer': ('1110', '0101'),
    'ACK_api_access': ('1111', '0110'),
    'ACK_banking_transaction': ('1001', '1000'),
    'ACK_payment_processing': ('1010', '1011'),
    'ACK_mathematical_operation': ('1111', '1100'),
    'ACK_data_analysis': ('1110', '1111'),
    'ACK_messaging': ('0000', '1111'),
    'ACK_email_exchange': ('0001', '0000'),
    'ACK_voice_communication': ('0011', '0001'),
    'ACK_streaming_access': ('0011', '0010'),
    'ACK_gaming_session': ('0101', '0100'),
    'ACK_content_download': ('0111', '0101'),
    'ACK_user_authentication': ('0111', '0110'),
    'ACK_network_configuration': ('1001', '1000'),
    'ACK_system_monitoring': ('1011', '1010')
}

@dataclass
class TemporalQuantumNetwork:
    """
    Implementation of the Temporal Quantum Network framework.
    Manages frequency bands, handshake patterns, and operation phases.
    """
    # Frequency bands with designated purposes
    BANDS: Dict[str, float] = None

    # Patterns define how we chunk bits for various operations
    QUANTUM_STATES: Dict[str, Tuple[str, str]] = None

    # Phase relationships for quantum operations
    OPERATION_PHASES: Dict[str, float] = None

    def __post_init__(self):
        # Initialize frequency bands if not provided
        if not self.BANDS:
            self.BANDS = {
                'ultra': 1.019,  # Network Control (dimension handshake, close)
                'high':  1.015,  # Quantum Computation
                'base':  1.013   # Data Transmission and other services
            }

        # Initialize handshake patterns if not provided
        if not self.QUANTUM_STATES:
            self.QUANTUM_STATES = {}
            for category, subcats in HANDSHAKE_PATTERNS.items():
                for subcat, chunks in subcats.items():
                    self.QUANTUM_STATES[subcat] = chunks

        # Initialize operation phases if not provided
        if not self.OPERATION_PHASES:
            self.OPERATION_PHASES = {
                'hadamard': math.pi/4,     # 45°
                'cnot':     3*math.pi/4,   # 135°
                'x':        5*math.pi/4,   # 225°
                'y':        math.pi/2,     # 90°
                'z':        7*math.pi/4    # 315°
            }

# ------------------------- CUDA Kernel for Waveform Generation ------------------------- #
@cuda.jit
def create_stable_state(output, frequency, phase, time_steps, noise_amplitude):
    """
    Generate a stable quantum state on the GPU.
    """
    idx = cuda.grid(1)
    if idx < output.size:
        t = (idx * time_steps) / output.size
        base_signal = math.sin(2.0 * math.pi * frequency * t + phase)
        noise = noise_amplitude * math.sin(2.0 * math.pi * frequency * t * 0.1)
        output[idx] = base_signal + noise

# ------------------------- Temporal Network Probe Class ------------------------- #
class TemporalNetworkProbe:
    """
    Orchestrates communications over the Temporal Quantum Network.
    Handles handshake transmissions, pattern probes, and system component checks.
    """
    def __init__(self):
        self.network = TemporalQuantumNetwork()
        self.threads_per_block = 256
        self.blocks = 4096
        self.sample_size = self.threads_per_block * self.blocks

        # Setup logging
        logging.basicConfig(level=logging.INFO, format='[%(asctime)s] [%(levelname)s] %(message)s')
        self.logger = logging.getLogger("TemporalNetworkProbe")

    # ------------------ Waveform Generation & Transmission ------------------ #
    def generate_stable_state(self, frequency_name: str, phase_idx: int, noise_amplitude: float = 0.05) -> Optional[np.ndarray]:
        """
        Generate one stable state using the specified frequency and phase index.
        """
        if frequency_name not in self.network.BANDS:
            self.logger.error(f"Unknown frequency band: {frequency_name}")
            return None

        output = np.zeros(self.sample_size, dtype=np.float32)
        frequency = self.network.BANDS[frequency_name]
        phase_list = list(self.network.OPERATION_PHASES.values())
        real_phase_idx = phase_idx % len(phase_list)
        phase = phase_list[real_phase_idx]

        d_output = cuda.to_device(output)
        create_stable_state[self.blocks, self.threads_per_block](
            d_output,
            frequency,
            phase,
            1e-9,  # time steps
            noise_amplitude
        )
        # Retrieve the wave locally for logging & checking
        state_data = d_output.copy_to_host()

        return state_data

    def check_response(self, state_data: np.ndarray) -> bool:
        """
        Analyze the received waveform and determine if the pattern was detected.
        Logs amplitude, coherence, stability, and detection confidence.
        """
        if state_data is None or state_data.size == 0:
            self.logger.error("Received empty state data.")
            return False

        amplitude = float(np.abs(np.mean(state_data)))
        coherence = float(np.abs(np.fft.fft(state_data)).max())
        stability = float(np.std(state_data))

        max_coherence = 741455.19  # Known maximum coherence
        threshold = 0.7 * max_coherence
        detected = coherence > threshold

        confidence = "High" if coherence > 0.9 * max_coherence else (
            "Low" if detected else "None"
        )

        # Log the response metrics
        self.logger.info(
            f"CheckResponse => Amp={amplitude:.6f}, Coh={coherence:.2f}, "
            f"Stab={stability:.6f}, Conf={confidence}, Detected={'Yes' if detected else 'No'}"
        )
        return detected

    def transmit_pattern(self, pattern_name: str, noise: float = 0.05):
        """
        Transmit a specific handshake pattern.
        Determines the frequency band based on the pattern's category.
        """
        # Find the category of the pattern
        category = None
        for cat, subcats in HANDSHAKE_PATTERNS.items():
            if pattern_name in subcats:
                category = cat
                break

        if not category:
            self.logger.error(f"Pattern '{pattern_name}' not found in any category.")
            return

        # Determine frequency band based on category
        if category == 'control':
            freq_name = 'ultra'
        elif category == 'computational_services':
            freq_name = 'high'
        else:
            freq_name = 'base'

        bits_pair = self.network.QUANTUM_STATES.get(pattern_name)
        if not bits_pair:
            self.logger.error(f"No quantum state defined for pattern '{pattern_name}'.")
            return

        self.logger.info(f"Transmitting '{pattern_name}' pattern on {freq_name} band.")

        for chunk in bits_pair:
            self.logger.info(f"  Chunk: {chunk}")
            for digit_char in chunk:
                try:
                    phase_idx = int(digit_char)
                except ValueError:
                    self.logger.error(f"Invalid digit character in chunk: {digit_char}")
                    continue
                # Transmit the phase index
                state_data = self.generate_stable_state(freq_name, phase_idx, noise_amplitude=noise)
                if state_data is None:
                    self.logger.error("Failed to generate stable state. Skipping transmission.")
                    continue
                detected = self.check_response(state_data)
                if detected:
                    self.logger.info(f"    Digit={digit_char}, Detected=Yes")
                else:
                    self.logger.warning(f"    Digit={digit_char}, Detected=No")
            time.sleep(0.1)  # Small delay between chunks

    def transmit_all_patterns(self, noise: float = 0.05):
        """
        Transmit all defined handshake patterns to perform a full probe of system components.
        """
        self.logger.info("Starting full system probe by transmitting all handshake patterns.")

        for category, subcats in HANDSHAKE_PATTERNS.items():
            for subcat in subcats.keys():
                self.transmit_pattern(subcat, noise=noise)
                time.sleep(0.2)  # Additional delay between patterns

        self.logger.info("Full system probe completed.")

    def transmit_custom_message(self, message: str, noise: float = 0.05):
        """
        Transmit a custom message using the messaging handshake pattern.
        This method initiates a messaging session, sends the message, and then terminates the session.
        """
        self.logger.info(f"Initiating messaging session for custom message: '{message}'")

        # Step 1: Initiate messaging session
        self.transmit_pattern('messaging', noise=noise)
        time.sleep(0.2)  # Small delay after initiating

        # Step 2: Transmit the message content as data patterns
        self.logger.info("Sending message content on BASE band.")
        for char in message:
            phase_idx = self.map_char_to_phase(char)
            wave = self.generate_stable_state('base', phase_idx, noise_amplitude=noise)
            if wave is None:
                self.logger.error(f"Failed to generate waveform for character '{char}'. Skipping.")
                continue
            detected = self.check_response(wave)
            if detected:
                self.logger.info(f"  Char='{char}' -> Phase Index={phase_idx}, Detected=Yes")
            else:
                self.logger.warning(f"  Char='{char}' -> Phase Index={phase_idx}, Detected=No")
                # Optional: Implement retry mechanism for failed detections
                self.logger.info(f"    Retrying transmission for character '{char}'.")
                wave_retry = self.generate_stable_state('base', phase_idx, noise_amplitude=noise)
                if wave_retry is not None:
                    detected_retry = self.check_response(wave_retry)
                    if detected_retry:
                        self.logger.info(f"    Retry Success: Char='{char}' -> Phase Index={phase_idx}, Detected=Yes")
                    else:
                        self.logger.error(f"    Retry Failed: Char='{char}' -> Phase Index={phase_idx}, Detected=No")
            time.sleep(0.05)  # Slightly faster transmission for messages

        # Step 3: Terminate messaging session
        self.transmit_pattern('messaging', noise=noise)
        self.logger.info("Messaging session terminated successfully.")

    def map_char_to_phase(self, char: str) -> int:
        """
        Map a character to a valid phase index based on the number of operation phases.
        Ensures consistent and valid phase indexing.
        """
        num_phases = len(self.network.OPERATION_PHASES)
        phase_idx = ord(char) % num_phases
        self.logger.debug(f"Mapping character '{char}' to Phase Index {phase_idx}")
        return phase_idx

    # ------------------------- Protocol Steps ------------------------- #
    def handshake_dimension(self):
        """
        Step 1: dimension_10 handshake on the ULTRA band
        """
        self.logger.info("Dimension handshake (base-10) on ULTRA band.")
        self.transmit_pattern('dimension_10')
        self.logger.info("Dimension handshake complete.")

    def perform_compute(self):
        """
        Step 2: 'mathematical_operation' and 'data_analysis' patterns on the HIGH band
        """
        self.logger.info("Performing compute steps on HIGH band.")
        self.transmit_pattern('mathematical_operation')
        self.transmit_pattern('data_analysis')

    def send_data(self):
        """
        Step 3: Transmit all data-related patterns on BASE band
        """
        self.logger.info("Sending data-related patterns on BASE band.")
        data_patterns = [
            'web_request', 'file_transfer', 'api_access',
            'banking_transaction', 'payment_processing',
            'messaging', 'email_exchange', 'voice_communication',
            'streaming_access', 'gaming_session', 'content_download',
            'user_authentication', 'network_configuration', 'system_monitoring'
        ]
        for pattern in data_patterns:
            self.transmit_pattern(pattern)
            time.sleep(0.1)  # Small delay between patterns

    def close_connection(self):
        """
        Step 4: 'close_connection' pattern on ULTRA band
        """
        self.logger.info("Closing connection with 'close_connection' pattern on ULTRA band.")
        self.transmit_pattern('close_connection')
        self.logger.info("Connection closed successfully.")

    # ------------------------- Full Protocol Execution ------------------------- #
    def full_network_probe(self):
        """
        Execute the complete Temporal Quantum Network protocol sequence:
        1. Dimension handshake
        2. Compute operations
        3. Data transmission
        4. Custom messaging
        5. Close connection
        """
        self.logger.info("=== Temporal Quantum Network Full Probe Start ===")
        self.logger.info("=============================================================")

        # Step 1: Dimension handshake
        self.handshake_dimension()
        time.sleep(0.5)

        # Step 2: Perform compute operations
        self.perform_compute()
        time.sleep(0.5)

        # Step 3: Send data-related patterns
        self.send_data()
        time.sleep(0.5)

        # Step 4: Transmit a custom message
        custom_msg = "HelloLaptop!"
        self.transmit_custom_message(custom_msg)
        time.sleep(0.5)

        # Step 5: Close connection
        self.close_connection()
        self.logger.info("=== Full Probe Protocol Complete ===")

    # ------------------------- Additional Probe Methods ------------------------- #
    def probe_system_components(self):
        """
        Additional method to probe individual system components as needed.
        """
        self.logger.info("Probing individual system components.")
        # Example: Probe specific patterns if needed
        specific_patterns = ['user_authentication', 'system_monitoring']
        for pattern in specific_patterns:
            self.transmit_pattern(pattern)
            time.sleep(0.1)
        self.logger.info("Individual system components probe completed.")

# ------------------------- Main Execution ------------------------- #
def main():
    probe = TemporalNetworkProbe()
    probe.full_network_probe()

if __name__ == "__main__":
    main()
# Out:
# [2025-01-16 19:21:29,920] [INFO] === Temporal Quantum Network Full Probe Start ===
# [2025-01-16 19:21:29,921] [INFO] =============================================================
# [2025-01-16 19:21:29,921] [INFO] Dimension handshake (base-10) on ULTRA band.
# [2025-01-16 19:21:29,922] [INFO] Transmitting 'dimension_10' pattern on ultra band.
# [2025-01-16 19:21:29,922] [INFO]   Chunk: 1010
# [2025-01-16 19:21:29,923] [INFO] init
# [2025-01-16 19:21:30,280] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:30,282] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:30,285] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:30,333] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:30,333] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:30,339] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:30,392] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:30,392] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:30,397] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:30,437] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:30,438] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:30,538] [INFO]   Chunk: 0101
# [2025-01-16 19:21:30,544] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:30,581] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:30,582] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:30,587] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:30,625] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:30,625] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:30,629] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:30,666] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:30,667] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:30,672] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:30,712] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:30,713] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:30,814] [INFO] Dimension handshake complete.
# [2025-01-16 19:21:31,316] [INFO] Performing compute steps on HIGH band.
# [2025-01-16 19:21:31,317] [INFO] Transmitting 'mathematical_operation' pattern on high band.
# [2025-01-16 19:21:31,318] [INFO]   Chunk: 1011
# [2025-01-16 19:21:31,322] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,366] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,366] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:31,371] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,407] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,408] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:31,412] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,451] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,452] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:31,457] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,458] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,458] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,459] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,459] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,460] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,460] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,461] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,462] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,462] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,463] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,463] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,502] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,502] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:31,603] [INFO]   Chunk: 1100
# [2025-01-16 19:21:31,609] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,650] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,651] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:31,655] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,694] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,694] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:31,698] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,736] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,737] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:31,740] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,779] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,779] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:31,881] [INFO] Transmitting 'data_analysis' pattern on high band.
# [2025-01-16 19:21:31,883] [INFO]   Chunk: 1101
# [2025-01-16 19:21:31,890] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,927] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,928] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:31,932] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:31,969] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:31,970] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:31,974] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,012] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:32,013] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:32,016] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,058] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:32,059] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:32,160] [INFO]   Chunk: 1110
# [2025-01-16 19:21:32,170] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,241] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:32,243] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:32,249] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,301] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:32,302] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:32,307] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,308] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,308] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,309] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,310] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,310] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,311] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,311] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,312] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,313] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,314] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,314] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,353] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:32,354] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:32,358] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:32,396] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:32,397] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,000] [INFO] Sending data-related patterns on BASE band.
# [2025-01-16 19:21:33,002] [INFO] Transmitting 'web_request' pattern on base band.
# [2025-01-16 19:21:33,004] [INFO]   Chunk: 0001
# [2025-01-16 19:21:33,012] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,053] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,054] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,059] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,101] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,102] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,105] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,146] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,147] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,151] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,190] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,191] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:33,292] [INFO]   Chunk: 0010
# [2025-01-16 19:21:33,298] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,346] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,347] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,352] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,392] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,393] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,399] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,438] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,438] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:33,442] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,479] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,480] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,682] [INFO] Transmitting 'file_transfer' pattern on base band.
# [2025-01-16 19:21:33,684] [INFO]   Chunk: 0011
# [2025-01-16 19:21:33,694] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,731] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,733] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,738] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,738] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,739] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,740] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,740] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,741] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,741] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,742] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,742] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,743] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,743] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,744] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,781] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,782] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:33,786] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,823] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,824] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:33,829] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:33,869] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:33,870] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:33,971] [INFO]   Chunk: 0100
# [2025-01-16 19:21:33,979] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,028] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,029] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:34,033] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,074] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,074] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:34,079] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,117] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,117] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:34,122] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,163] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,164] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:34,366] [INFO] Transmitting 'api_access' pattern on base band.
# [2025-01-16 19:21:34,369] [INFO]   Chunk: 0101
# [2025-01-16 19:21:34,378] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,424] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,424] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:34,428] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,468] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,469] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:34,473] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,517] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,518] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:34,524] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,608] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,609] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:34,711] [INFO]   Chunk: 0110
# [2025-01-16 19:21:34,722] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,723] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,724] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,726] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,726] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,727] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,728] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,729] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,730] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,730] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,731] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,732] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,771] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,771] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:34,775] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,814] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,814] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:34,818] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,857] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,857] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:34,862] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:34,899] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:34,900] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:35,102] [INFO] Transmitting 'banking_transaction' pattern on base band.
# [2025-01-16 19:21:35,103] [INFO]   Chunk: 0111
# [2025-01-16 19:21:35,109] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,151] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,152] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:35,156] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,203] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,204] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:35,209] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,253] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,254] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:35,261] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,313] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,314] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:35,414] [INFO]   Chunk: 1000
# [2025-01-16 19:21:35,421] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,461] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,462] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:35,466] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,506] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,507] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:35,513] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,550] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,550] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:35,555] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,556] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,557] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,557] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,558] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,559] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,559] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,560] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,560] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,560] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,561] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,561] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,605] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,606] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:35,807] [INFO] Transmitting 'payment_processing' pattern on base band.
# [2025-01-16 19:21:35,809] [INFO]   Chunk: 1001
# [2025-01-16 19:21:35,816] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,858] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,859] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:35,863] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,900] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,900] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:35,904] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:35,993] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:35,994] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:36,000] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,058] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,059] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:36,160] [INFO]   Chunk: 1010
# [2025-01-16 19:21:36,166] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,204] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,205] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:36,209] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,246] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,247] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:36,251] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,289] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,290] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:36,295] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,332] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,332] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:36,534] [INFO] Transmitting 'messaging' pattern on base band.
# [2025-01-16 19:21:36,536] [INFO]   Chunk: 1111
# [2025-01-16 19:21:36,542] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,583] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,584] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:36,588] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,631] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,633] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:36,637] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,637] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,638] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,638] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,639] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,639] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,640] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,640] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,641] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,641] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,641] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,642] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,681] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,682] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:36,685] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,723] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,723] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:36,825] [INFO]   Chunk: 0000
# [2025-01-16 19:21:36,840] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,883] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,884] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:36,895] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,936] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,937] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:36,949] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:36,991] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:36,992] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,004] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,043] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,044] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,246] [INFO] Transmitting 'email_exchange' pattern on base band.
# [2025-01-16 19:21:37,247] [INFO]   Chunk: 0000
# [2025-01-16 19:21:37,262] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,328] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,329] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,342] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,402] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,402] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,414] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,456] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,456] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,468] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,525] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,526] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,627] [INFO]   Chunk: 0001
# [2025-01-16 19:21:37,644] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,683] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,683] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,696] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,697] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,699] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,700] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,701] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,701] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,702] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,703] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,704] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,704] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,705] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,706] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,746] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,747] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,760] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,797] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,798] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:37,812] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:37,851] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:37,852] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:38,054] [INFO] Transmitting 'voice_communication' pattern on base band.
# [2025-01-16 19:21:38,056] [INFO]   Chunk: 0001
# [2025-01-16 19:21:38,072] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,115] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,116] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:38,130] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,168] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,169] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:38,183] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,226] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,226] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:38,240] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,280] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,281] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:38,382] [INFO]   Chunk: 0011
# [2025-01-16 19:21:38,400] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,480] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,481] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:38,498] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,558] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,559] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:38,575] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,619] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,620] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:38,640] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,683] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,684] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:38,886] [INFO] Transmitting 'streaming_access' pattern on base band.
# [2025-01-16 19:21:38,889] [INFO]   Chunk: 0010
# [2025-01-16 19:21:38,908] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,909] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,910] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,911] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,911] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,912] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,913] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,914] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,914] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,915] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,916] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,917] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:38,962] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:38,963] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:38,978] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,017] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,017] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:39,033] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,072] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,072] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:39,088] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,125] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,126] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:39,227] [INFO]   Chunk: 0011
# [2025-01-16 19:21:39,247] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,293] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,293] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:39,309] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,352] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,352] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:39,369] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,409] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,410] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:39,427] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,495] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,496] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:39,699] [INFO] Transmitting 'gaming_session' pattern on base band.
# [2025-01-16 19:21:39,701] [INFO]   Chunk: 0100
# [2025-01-16 19:21:39,721] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,760] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,761] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:39,777] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,815] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,816] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:39,832] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,868] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,868] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:39,884] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,885] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,886] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,887] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,887] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,888] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,888] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,889] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,889] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,890] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,890] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,891] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:39,931] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:39,932] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:40,033] [INFO]   Chunk: 0101
# [2025-01-16 19:21:40,052] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,098] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,099] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:40,115] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,154] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,155] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:40,171] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,212] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,213] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:40,229] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,265] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,266] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:40,468] [INFO] Transmitting 'content_download' pattern on base band.
# [2025-01-16 19:21:40,470] [INFO]   Chunk: 0101
# [2025-01-16 19:21:40,490] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,577] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,578] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:40,594] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,647] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,648] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:40,665] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,714] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,715] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:40,732] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,774] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,775] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:40,876] [INFO]   Chunk: 0111
# [2025-01-16 19:21:40,897] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:40,939] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:40,940] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:40,956] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,002] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,003] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:41,019] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,020] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,021] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,022] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,022] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,023] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,023] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,024] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,024] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,025] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,025] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,026] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,072] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,073] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:41,089] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,140] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,141] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:41,343] [INFO] Transmitting 'user_authentication' pattern on base band.
# [2025-01-16 19:21:41,344] [INFO]   Chunk: 0110
# [2025-01-16 19:21:41,361] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,404] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,405] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:41,422] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,465] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,465] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:41,481] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,521] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,521] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:41,539] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,621] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,622] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:41,723] [INFO]   Chunk: 0111
# [2025-01-16 19:21:41,743] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,785] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,786] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:41,803] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,844] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,844] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:41,861] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,905] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,906] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:41,922] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:41,962] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:41,962] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:42,165] [INFO] Transmitting 'network_configuration' pattern on base band.
# [2025-01-16 19:21:42,167] [INFO]   Chunk: 1000
# [2025-01-16 19:21:42,185] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,232] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:42,233] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:42,249] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,250] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,251] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,252] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,253] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,254] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,255] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,255] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,256] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,257] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,257] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,258] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,296] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:42,296] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:42,312] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,357] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:42,358] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:42,374] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,413] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:42,413] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:42,514] [INFO]   Chunk: 1001
# [2025-01-16 19:21:42,533] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,576] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:42,576] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:42,592] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,629] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:42,630] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:42,647] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,690] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:42,691] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:42,707] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:42,747] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:42,748] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:42,949] [INFO] Transmitting 'system_monitoring' pattern on base band.
# [2025-01-16 19:21:42,950] [INFO]   Chunk: 1010
# [2025-01-16 19:21:42,966] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,003] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:43,004] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:43,020] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,057] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:43,058] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:43,074] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,113] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:43,113] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:43,129] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,167] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:43,168] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:43,269] [INFO]   Chunk: 1011
# [2025-01-16 19:21:43,285] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,286] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,288] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,289] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,290] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,291] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,291] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,292] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,293] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,294] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,295] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,296] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,334] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:43,335] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:43,350] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,395] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:43,396] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:43,412] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,493] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:43,495] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:43,512] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:43,558] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:43,558] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:44,261] [INFO] Initiating messaging session for custom message: 'HelloLaptop!'
# [2025-01-16 19:21:44,264] [INFO] Transmitting 'messaging' pattern on base band.
# [2025-01-16 19:21:44,266] [INFO]   Chunk: 1111
# [2025-01-16 19:21:44,283] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,323] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:44,323] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:44,339] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,380] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:44,381] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:44,397] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,435] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:44,436] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:44,452] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,493] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:44,493] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:44,594] [INFO]   Chunk: 0000
# [2025-01-16 19:21:44,614] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,654] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:44,654] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:44,670] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,708] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:44,709] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:44,726] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,768] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:44,769] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:44,786] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,786] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,788] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,789] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,790] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,791] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,792] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,792] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,793] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,794] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,794] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,795] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:44,843] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:44,844] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:45,146] [INFO] Sending message content on BASE band.
# [2025-01-16 19:21:45,164] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:45,207] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:45,208] [INFO]   Char='H' -> Phase Index=2, Detected=Yes
# [2025-01-16 19:21:45,274] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:45,316] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:45,317] [INFO]   Char='e' -> Phase Index=1, Detected=Yes
# [2025-01-16 19:21:45,383] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:45,437] [INFO] CheckResponse => Amp=1.000000, Coh=1048576.00, Stab=0.000000, Conf=High, Detected=Yes
# [2025-01-16 19:21:45,438] [INFO]   Char='l' -> Phase Index=3, Detected=Yes
# [2025-01-16 19:21:45,506] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:45,554] [INFO] CheckResponse => Amp=1.000000, Coh=1048576.00, Stab=0.000000, Conf=High, Detected=Yes
# [2025-01-16 19:21:45,555] [INFO]   Char='l' -> Phase Index=3, Detected=Yes
# [2025-01-16 19:21:45,622] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:45,697] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:45,698] [INFO]   Char='o' -> Phase Index=1, Detected=Yes
# [2025-01-16 19:21:45,766] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:45,810] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:45,811] [INFO]   Char='L' -> Phase Index=1, Detected=Yes
# [2025-01-16 19:21:45,880] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:45,923] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:45,924] [INFO]   Char='a' -> Phase Index=2, Detected=Yes
# [2025-01-16 19:21:45,993] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,042] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,042] [INFO]   Char='p' -> Phase Index=2, Detected=Yes
# [2025-01-16 19:21:46,110] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,194] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,195] [INFO]   Char='t' -> Phase Index=1, Detected=Yes
# [2025-01-16 19:21:46,263] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,311] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,312] [INFO]   Char='o' -> Phase Index=1, Detected=Yes
# [2025-01-16 19:21:46,379] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,380] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,381] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,382] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,383] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,384] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,384] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,385] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,386] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,386] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,387] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,388] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,427] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,427] [INFO]   Char='p' -> Phase Index=2, Detected=Yes
# [2025-01-16 19:21:46,495] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,538] [INFO] CheckResponse => Amp=1.000000, Coh=1048576.00, Stab=0.000000, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,539] [INFO]   Char='!' -> Phase Index=3, Detected=Yes
# [2025-01-16 19:21:46,590] [INFO] Transmitting 'messaging' pattern on base band.
# [2025-01-16 19:21:46,591] [INFO]   Chunk: 1111
# [2025-01-16 19:21:46,608] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,649] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,649] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:46,665] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,708] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,709] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:46,725] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,763] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,763] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:46,779] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:46,845] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:46,846] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:46,947] [INFO]   Chunk: 0000
# [2025-01-16 19:21:46,966] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,004] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:47,005] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:47,021] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,062] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:47,063] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:47,079] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,128] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:47,129] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:47,145] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,184] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:47,185] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:47,286] [INFO] Messaging session terminated successfully.
# [2025-01-16 19:21:47,788] [INFO] Closing connection with 'close_connection' pattern on ULTRA band.
# [2025-01-16 19:21:47,790] [INFO] Transmitting 'close_connection' pattern on ultra band.
# [2025-01-16 19:21:47,792] [INFO]   Chunk: 1111
# [2025-01-16 19:21:47,810] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,857] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:47,859] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:47,875] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,876] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,877] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,878] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,879] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,880] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,881] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,881] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,882] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,883] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,883] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,884] [INFO] dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:47,931] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:47,932] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:47,947] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:48,022] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:48,024] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:48,040] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:48,099] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:48,100] [INFO]     Digit=1, Detected=Yes
# [2025-01-16 19:21:48,202] [INFO]   Chunk: 0000
# [2025-01-16 19:21:48,221] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:48,267] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:48,268] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:48,283] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:48,326] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:48,327] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:48,343] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:48,383] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:48,384] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:48,400] [INFO] add pending dealloc: cuMemFree_v2 4194304 bytes
# [2025-01-16 19:21:48,439] [INFO] CheckResponse => Amp=0.707107, Coh=741455.19, Stab=0.000001, Conf=High, Detected=Yes
# [2025-01-16 19:21:48,440] [INFO]     Digit=0, Detected=Yes
# [2025-01-16 19:21:48,542] [INFO] Connection closed successfully.
# [2025-01-16 19:21:48,545] [INFO] === Full Probe Protocol Complete ===
